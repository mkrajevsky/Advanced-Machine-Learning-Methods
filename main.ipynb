# %%
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !source .venv/bin/activate

# %%
# Out:
#             Sygnatura czasowa Nazwa użytkownika Łączny wynik Unnamed: 3  \
# 0  2025/11/17 12:13:52 PM CET          fg@wp.pl   14.00 / 25   LinkedIn
#
#     [wynik]   [ocena] Unnamed: 6  [wynik].1   [ocena].1 Unnamed: 9  ...  \
# 0  1.00 / 1       NaN   LinkedIn   0.00 / 1         NaN   Interpol  ...
#
#    [ocena].21  Unnamed: 69  [wynik].22  [ocena].22  Unnamed: 72  [wynik].23  \
# 0         NaN     Interpol    0.00 / 1         NaN     Interpol    0.00 / 1
#
#    [ocena].23  Unnamed: 75  [wynik].24  [ocena].24
# 0         NaN     LinkedIn    1.00 / 1         NaN
#
# [1 rows x 78 columns]
